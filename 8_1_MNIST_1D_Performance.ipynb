# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
#%pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 10   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
    # TO DO:
    # # Initialize the parameters with He initialization
      if isinstance(layer_in, torch.nn.Linear):
        torch.nn.init.kaiming_normal_(layer_in.weight)
        if layer_in.bias is not None:
            layer_in.bias.data.fill_(0.0)
            
      print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 2.082923, train error 79.90,  test loss 2.083944, test error 79.70
# Epoch     1, train loss 1.731860, train error 68.47,  test loss 1.733648, test error 72.50
# Epoch     2, train loss 1.659679, train error 67.30,  test loss 1.680252, test error 69.30
# Epoch     3, train loss 1.641884, train error 66.88,  test loss 1.664112, test error 69.10
# Epoch     4, train loss 1.589692, train error 65.65,  test loss 1.618000, test error 68.00
# Epoch     5, train loss 1.526866, train error 59.97,  test loss 1.561531, test error 63.70
# Epoch     6, train loss 1.478240, train error 58.97,  test loss 1.508283, test error 61.10
# Epoch     7, train loss 1.429014, train error 54.67,  test loss 1.440143, test error 56.30
# Epoch     8, train loss 1.439230, train error 58.30,  test loss 1.458687, test error 60.00
# Epoch     9, train loss 1.388858, train error 53.12,  test loss 1.410226, test error 55.60
# Epoch    10, train loss 1.359849, train error 52.60,  test loss 1.391786, test error 55.50
# Epoch    11, train loss 1.344008, train error 52.55,  test loss 1.371879, test error 55.70
# Epoch    12, train loss 1.356182, train error 54.42,  test loss 1.385919, test error 57.70
# Epoch    13, train loss 1.326409, train error 51.05,  test loss 1.354487, test error 54.20
# Epoch    14, train loss 1.335585, train error 52.60,  test loss 1.377733, test error 55.60
# Epoch    15, train loss 1.310563, train error 50.42,  test loss 1.354499, test error 53.50
# Epoch    16, train loss 1.313670, train error 50.72,  test loss 1.356285, test error 53.90
# Epoch    17, train loss 1.304644, train error 51.35,  test loss 1.356981, test error 54.80
# Epoch    18, train loss 1.292753, train error 49.92,  test loss 1.342236, test error 53.70
# Epoch    19, train loss 1.291933, train error 50.75,  test loss 1.343498, test error 53.50
# Epoch    20, train loss 1.279719, train error 49.45,  test loss 1.338043, test error 55.40
# Epoch    21, train loss 1.275514, train error 49.12,  test loss 1.336690, test error 53.50
# Epoch    22, train loss 1.272234, train error 48.92,  test loss 1.335850, test error 52.90
# Epoch    23, train loss 1.275193, train error 50.08,  test loss 1.348843, test error 54.50
# Epoch    24, train loss 1.268332, train error 49.10,  test loss 1.342603, test error 54.10
# Epoch    25, train loss 1.265507, train error 48.75,  test loss 1.338716, test error 53.90
# Epoch    26, train loss 1.261944, train error 48.50,  test loss 1.338995, test error 54.20
# Epoch    27, train loss 1.260677, train error 48.47,  test loss 1.332502, test error 53.80
# Epoch    28, train loss 1.262475, train error 49.12,  test loss 1.331905, test error 53.80
# Epoch    29, train loss 1.259028, train error 48.83,  test loss 1.338418, test error 53.90
# Epoch    30, train loss 1.253763, train error 48.78,  test loss 1.331964, test error 53.50
# Epoch    31, train loss 1.254035, train error 48.88,  test loss 1.332788, test error 54.50
# Epoch    32, train loss 1.250528, train error 48.50,  test loss 1.330835, test error 54.60
# Epoch    33, train loss 1.249817, train error 48.58,  test loss 1.331599, test error 54.20
# Epoch    34, train loss 1.249434, train error 48.92,  test loss 1.332521, test error 54.60
# Epoch    35, train loss 1.248928, train error 48.72,  test loss 1.332563, test error 54.50
# Epoch    36, train loss 1.248039, train error 48.50,  test loss 1.331676, test error 54.20
# Epoch    37, train loss 1.249090, train error 48.80,  test loss 1.331733, test error 54.10
# Epoch    38, train loss 1.247581, train error 48.85,  test loss 1.331909, test error 54.20
# Epoch    39, train loss 1.246166, train error 48.75,  test loss 1.331182, test error 53.60
# Epoch    40, train loss 1.244152, train error 48.42,  test loss 1.330587, test error 54.20
# Epoch    41, train loss 1.243115, train error 48.62,  test loss 1.330220, test error 54.30
# Epoch    42, train loss 1.242482, train error 48.55,  test loss 1.328951, test error 53.90
# Epoch    43, train loss 1.242327, train error 48.53,  test loss 1.328218, test error 53.80
# Epoch    44, train loss 1.241543, train error 48.50,  test loss 1.329553, test error 53.30
# Epoch    45, train loss 1.241894, train error 48.75,  test loss 1.328829, test error 53.50
# Epoch    46, train loss 1.241301, train error 48.72,  test loss 1.327919, test error 54.20
# Epoch    47, train loss 1.241501, train error 48.40,  test loss 1.331462, test error 54.00
# Epoch    48, train loss 1.239918, train error 48.38,  test loss 1.328015, test error 54.10
# Epoch    49, train loss 1.240397, train error 48.50,  test loss 1.328517, test error 54.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
#     the final result will be a good estimate of true performance. Decreasing the hidden units increased performance dramatically.
